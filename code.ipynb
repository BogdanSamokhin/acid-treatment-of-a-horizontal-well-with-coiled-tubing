# %% [markdown]
# ## Переменные

# %%
H: float,#высота скважины ГС(определение при наклонной ГС?)(данные о скважине)
L: float,#длина ГС(данные о скважине)(обезразмеривание)
segments: list,#список с длинами сегметов для кислотной обработки(данные о скважине)
C_segments: list,#список с массовыми концетрациями кислоты для каждого сегмента(начальное условие)
q_w: float,#заданный расход на скважине(начальное условие)
r_w0: float,#начальный радиус скважины(начальное условие)
D_nkt: float,#внешний диаметр нкт(начальное условие)
t_star: float,#заднное в методичке время обезразмериванния(начальное условие)(обезразмеривание)
P_k: float,#давление задающееся для усреднения стр 21(начальное условие)
V: float,#reverse speed для нкт(начальное условие)
k: float,#проницаемость (пласта или трубы? изменяется с временем k(t)?)
m: float,#коэффециент пористости
P_ust: float,#устьевое давление скважины (задается как const?)
alpha: float,#угол отклонения ствола ГС от вертикали
p: float,#плотность кислоты или водяного раствора закачиваемого в скважину
g: float,#ускорение свободного падения
mu: float, #динамическая вязкость жидкости,
d_nkt: float, #внутренний диаметр нкт
xi: float, #коэффициент пъезопроводности продуктивного пласта 𝑘/𝜇(𝑚𝛽 + 𝛽𝑐)
# Out:
#   Input In [1]
#     H: float,#высота скважины ГС(определение при наклонной ГС?)(данные о скважине)
#             ^
# SyntaxError: invalid syntax

# %%
H: float
L: float

# %% [markdown]
# ![image.png](attachment:image.png)
# стр 11

# %%
segments: list # массив с данными о метках сегментов
C_segments: list #массив с массовыми концетрациями кислоты для каждого сегмента(начальное условие)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image.png](attachment:image-2.png)
# стр 31

# %%
q_w: float,#заданный расход на скважине(начальное условие)

# %% [markdown]
# ![image.png](attachment:image.png)
# стр 30

# %%
r_w0: float ?
D_w: float,#диаметр долота

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image.png](attachment:image-2.png)
# ![image.png](attachment:image-3.png)
# ![image.png](attachment:image-4.png)
# стр 15-17

# %%
d_nkt: float 
D_nkt: float - ?????????!!!!!!!!!!!! соотношение с d_nkt

# %% [markdown]
# ![image.png](attachment:image.png)
# стр 30

# %%
R(x,t)

# %% [markdown]
# ![image.png](attachment:image.png)
# стр 22

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
t_star: float,#заднное в методичке время обезразмериванния(начальное условие)(обезразмеривание)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
P_k: float,#давление задающееся для усреднения стр 21(начальное условие)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
V: float,#reverse speed для нкт(начальное условие)
k: float,#проницаемость (пласта или трубы? изменяется с временем k(t)?)
m: float,#коэффециент пористости

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image.png](attachment:image-2.png)

# %%
P_ust: float,#устьевое давление скважины (задается как const?)
alpha: float,#угол отклонения ствола ГС от вертикали

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
p: float,#плотность кислоты или водяного раствора закачиваемого в скважину(очень много плотностей разобраться)
g: float,#ускорение свободного падения

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
mu: float, #динамическая вязкость жидкости,
xi: float, #коэффициент пъезопроводности продуктивного пласта 𝑘/𝜇(𝑚𝛽 + 𝛽𝑐)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image.png](attachment:image-2.png)

# %% [markdown]
# ## Начальные и граничные условия

# %% [markdown]
# Начальные и граничные условия на давление

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image.png](attachment:image-2.png)
# ![image.png](attachment:image-3.png)
# ![image.png](attachment:image-4.png)

# %% [markdown]
# Общая схема дифференциальных уравнений для давления

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image.png](attachment:image-2.png)

# %% [markdown]
# Предпологается, что дифф уры написаны для полости внутри гнкт, для нахождения граничных условий к уравнению бернулли

# %% [markdown]
# Начальные и граничные условия на скорость потока(вещество растворитель с карбонатом)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# U ищется для трубопровода или для гнкт?

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image.png](attachment:image-2.png)

# %% [markdown]
# Начальные и граничные условия на U

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Начальные и граничные условия на P

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Уравнение подвижной границы

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Начальные и граничыне условия на концетрацию кислоты и радиус трубопровода

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image.png](attachment:image-2.png)
